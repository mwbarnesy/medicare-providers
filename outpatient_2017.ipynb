# %% [markdown]
# ### Hospital Outpatient 2017 - Health Care Blue Book

# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# %matplotlib inline

# %%
outpatient_2017 = pd.read_excel('data/MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx', skiprows = [0, 1, 2, 3, 4])

# %%
outpatient_2017.head(10)
# Out:
#    Provider ID                     Provider Name Provider Street Address  \
# 0        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 1        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 2        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 3        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 4        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 5        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 6        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 7        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 8        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
# 9        10001  Southeast Alabama Medical Center  1108 Ross Clark Circle
#
#   Provider City Provider\nState  Provider\nZip Code  \
# 0        Dothan              AL               36301
# 1        Dothan              AL               36301
# 2        Dothan              AL               36301
# 3        Dothan              AL               36301
# 4        Dothan              AL               36301
# 5        Dothan              AL               36301
# 6        Dothan              AL               36301
# 7        Dothan              AL               36301
# 8        Dothan              AL               36301
# 9        Dothan              AL               36301
#
#   Provider\nHospital Referral Region\n(HRR)   APC  \
# 0                               AL - Dothan  5072
# 1                               AL - Dothan  5073
# 2                               AL - Dothan  5091
# 3                               AL - Dothan  5092
# 4                               AL - Dothan  5112
# 5                               AL - Dothan  5113
# 6                               AL - Dothan  5114
# 7                               AL - Dothan  5115
# 8                               AL - Dothan  5153
# 9                               AL - Dothan  5154
#
#                                     APC\nDescription  Beneficiaries  \
# 0    Level 2 Excision/ Biopsy/ Incision and Drainage          249.0
# 1    Level 3 Excision/ Biopsy/ Incision and Drainage           52.0
# 2  Level 1 Breast/Lymphatic Surgery and Related P...           26.0
# 3  Level 2 Breast/Lymphatic Surgery and Related P...           23.0
# 4                 Level 2 Musculoskeletal Procedures           17.0
# 5                 Level 3 Musculoskeletal Procedures           65.0
# 6                 Level 4 Musculoskeletal Procedures          173.0
# 7                 Level 5 Musculoskeletal Procedures           59.0
# 8                           Level 3 Airway Endoscopy           20.0
# 9                           Level 4 Airway Endoscopy           28.0
#
#    Comprehensive APC\nServices  Average\nEstimated\nTotal\nSubmitted\nCharges  \
# 0                          259                                    9575.005714
# 1                           53                                   12578.280189
# 2                           27                                   11337.608889
# 3                           23                                   17116.158261
# 4                           17                                    7382.732353
# 5                           68                                   12500.444118
# 6                          175                                   20738.622343
# 7                           59                                   32460.513729
# 8                           20                                    8477.084000
# 9                           28                                    9904.532857
#
#    Average\nMedicare\nAllowed\nAmount  Average\nMedicare\nPayment\nAmount  \
# 0                         1038.454672                          826.277954
# 1                         1792.596792                         1423.246792
# 2                         2113.580000                         1683.990000
# 3                         3737.140000                         2977.550000
# 4                         1029.460000                          820.210000
# 5                         1970.914706                         1570.323529
# 6                         4399.540114                         3502.090114
# 7                         8078.530000                         6762.530000
# 8                         1073.750000                          855.510000
# 9                         1974.128214                         1556.268214
#
#    Outlier\nComprehensive\nAPC\nServices  Average\nMedicare\nOutlier\nAmount
# 0                                    NaN                                 NaN
# 1                                    NaN                                 NaN
# 2                                    0.0                                 0.0
# 3                                    0.0                                 0.0
# 4                                    0.0                                 0.0
# 5                                    0.0                                 0.0
# 6                                    0.0                                 0.0
# 7                                    0.0                                 0.0
# 8                                    0.0                                 0.0
# 9                                    0.0                                 0.0

# %%
#pd.DataFrame(np.arange(12).reshape(3,4), columns=['P', 'Q', 'R', 'S'])

# %% [markdown]
# #### Renaming columns isn't necessary, but here's the code just in case
#
# outpatient_2017 = outpatient_2017.rename(columns = {
#     'Unnamed: 0' : 'Provider ID',
#     'Unnamed: 1' : 'Provider Name',
#     'Unnamed: 2' : 'Provider Street Address',
#     'Unnamed: 3' : 'Provider City',
#     'Unnamed: 4' : 'Provider State',
#     'Unnamed: 5' : 'Provider Zip Code',
#     'Unnamed: 6' : 'Provider Hospital Referral Region (HRR)',
#     'Unnamed: 7' : 'APC',
#     'Unnamed: 8' : 'APC Description',
#     'Unnamed: 9' : 'Beneficiaries',
#     'Unnamed: 10' : 'Comprehensive APC Services',
#     'Unnamed: 11' : 'Average Estimated Total Submitted Charges',
#     'Unnamed: 12' : 'Average Medicare Allowed Amount',
#     'Unnamed: 13' : 'Average Medicare Payment Amount',
#     'Unnamed: 14' : 'Outlier Comprehensive APC Services',
#     'Unnamed: 15' : 'Average Medicare Outlier Amount'})
