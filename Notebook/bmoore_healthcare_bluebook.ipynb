# %%
import pandas as pd 
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Medicare *Provider* Utilization and Payment Data Phys & Others, CY 2017
# # Large Dataset

# %%
#read in the .txt file as a .csv
med_prov_pmnt = pd.read_csv('../data/Medicare_Provider_Util_Payment_PUF_CY2017.txt', sep='\t', header=0)
med_prov_pmnt.head()
# Out:
# C:\Users\brand\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           npi                       nppes_provider_last_org_name  \
# 0           1  CPT copyright 2016 American Medical Associatio...
# 1  1003000126                                          ENKESHAFI
# 2  1003000126                                          ENKESHAFI
# 3  1003000126                                          ENKESHAFI
# 4  1003000126                                          ENKESHAFI
#
#   nppes_provider_first_name nppes_provider_mi nppes_credentials  \
# 0                       NaN               NaN               NaN
# 1                   ARDALAN               NaN              M.D.
# 2                   ARDALAN               NaN              M.D.
# 3                   ARDALAN               NaN              M.D.
# ...

# %%
#drop the unnecessary first row and reset the df index
#look at the first 5 rows
med_prov_pmnt = med_prov_pmnt.drop([0])
med_prov_pmnt = med_prov_pmnt.reset_index(drop=True)
med_prov_pmnt.head()
# Out:
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0               NaN              M.D.                     M                 I
# 1               NaN              M.D.                     M                 I
# 2               NaN              M.D.                     M                 I
# 3               NaN              M.D.                     M                 I
# 4               NaN              M.D.                     M                 I
#
#   nppes_provider_street1 nppes_provider_street2 nppes_provider_city  ...  \
# ...

# %%
#look at the last five rows
med_prov_pmnt.tail()
# Out:
#                 npi nppes_provider_last_org_name nppes_provider_first_name  \
# 9847438  1992999825                    DESCHENES                  GEOFFREY
# 9847439  1992999874                        JOFFE                 GABRIELLA
# 9847440  1992999874                        JOFFE                 GABRIELLA
# 9847441  1992999874                        JOFFE                 GABRIELLA
# 9847442  1992999874                        JOFFE                 GABRIELLA
#
#         nppes_provider_mi nppes_credentials nppes_provider_gender  \
# 9847438                 R              M.D.                     M
# 9847439               NaN               NaN                     F
# 9847440               NaN               NaN                     F
# 9847441               NaN               NaN                     F
# 9847442               NaN               NaN                     F
#
#         nppes_entity_code nppes_provider_street1 nppes_provider_street2  \
# ...

# %%
#check to see that we have all rows and columns
med_prov_pmnt.shape
# Out:
# (9847443, 26)

# %% [markdown]
# **POSSIBLE DELETIONS:**
#
# we can get rid of: nppes_provider_mi, nppes_credentials, nppes_provider_street1, nppes_provider_street2, hcpcs_drug_indicator
#
# (possibly) hcpcs_drug_indicator, average_Medicare_standard_amt

# %%
#look at the type of datatypes we have
print(med_prov_pmnt.dtypes)
# Out:
# npi                                   int64
# nppes_provider_last_org_name         object
# nppes_provider_first_name            object
# nppes_provider_mi                    object
# nppes_credentials                    object
# nppes_provider_gender                object
# nppes_entity_code                    object
# nppes_provider_street1               object
# nppes_provider_street2               object
# nppes_provider_city                  object
# nppes_provider_zip                   object
# nppes_provider_state                 object
# nppes_provider_country               object
# provider_type                        object
# medicare_participation_indicator     object
# place_of_service                     object
# hcpcs_code                           object
# hcpcs_description                    object
# hcpcs_drug_indicator                 object
# line_srvc_cnt                       float64
# bene_unique_cnt                     float64
# ...

# %% [markdown]
# **The Measure columns will probably need to be converted to floats**
